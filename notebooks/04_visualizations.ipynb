# %% [markdown]
# # 📈 04_visualizations.ipynb
#
# Visuals for KPIs.

# %%
import pandas as pd
import plotly.express as px
from src.kpis import calculate_business_kpis

df = pd.read_csv('../data/processed/real_estate_processed_data.csv', parse_dates=['date'])
biz = calculate_business_kpis(df)
fig = px.line(biz['monthly_transactions'], x='date', y='transaction_volume', title='Monthly Transactions')
fig.show()
