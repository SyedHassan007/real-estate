# %% [markdown]
# # ⚙️ 03_kpi_engineering.ipynb
#
# Compute KPIs.

# %%
import pandas as pd
from src.kpis import calculate_business_kpis, calculate_customer_kpis

df = pd.read_csv('../data/processed/real_estate_processed_data.csv', parse_dates=['date'])
print(calculate_business_kpis(df).keys())
print(calculate_customer_kpis(df).keys())
