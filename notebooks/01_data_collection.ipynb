# %% [markdown]
# # 🏡 01_data_collection.ipynb
#
# Generate synthetic dataset.

# %%
from src.data_generator import generate_real_estate_data
from datetime import date
import pandas as pd

df = generate_real_estate_data(10000, date(2024,1,1), date(2024,12,31))
df.to_csv('../data/raw/real_estate_raw_data.csv', index=False)
print('Saved raw dataset.')
